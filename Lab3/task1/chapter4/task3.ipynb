# %% [markdown]
# 1.For non changable variables we use uppercase letters in const naming.
# but, if some of the variable might be change value in the flow of time we don't want to use uppercase for that naming.
